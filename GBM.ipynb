# %%
from aleatory.processes import GBM

# %%
GBM = GBM(drift=0.3, volatility=0.2, initial=100, T=1, rng=None)

# %%
GBM.draw(n=252, N=10000, figsize=(12, 7), style='Solarize_Light2',envelope = True)

# %%
GBM.estimate_expectations()
# Out:
# [100.0,
#  100.1109621968493,
#  100.24500738936527,
#  100.37786064787757,
#  100.49295003055792,
#  100.61568331663902,
#  100.7339400653171,
#  100.85582597214916,
#  100.97587822426414,
#  101.10295923864854,
#  101.22262728246399,
#  101.36029980349625,
#  101.48227842115091,
#  101.59210764003522,
#  101.7058709235089,
#  101.80705788985567,
#  101.9330415590552,
#  102.04936472593103,
#  102.15206717781997,
#  102.25456402185678,
#  102.35876166168923,
#  102.48164557512912,
#  102.60049623556522,
#  102.71156807509321,
#  102.83942925142236,
#  102.97161175388511,
#  103.11031451218538,
#  103.25631384625889,
#  103.38936872863069,
#  103.52532666090104,
#  103.64558307702005,
#  103.79169144925005,
#  103.91090798635987,
#  104.03048570850024,
#  104.17981964679221,
#  104.30834421462121,
#  104.42884040226869,
#  104.55417274112894,
#  104.70779439027616,
#  104.83343891431542,
#  104.96591617409302,
#  105.0630530343696,
#  105.17735181283085,
#  105.29889608198725,
# ...
